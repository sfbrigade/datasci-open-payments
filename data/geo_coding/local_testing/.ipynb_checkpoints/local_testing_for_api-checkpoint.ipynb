# %%
import os
import pandas as pd
import requests
import sqlalchemy as sqla
import sys

pd.options.display.max_columns = 999

import censusgeocode as cg
from sqlalchemy import create_engine

# %%
df = pd.read_csv("op_dataset_1.csv")

# %%
df.head()
# Out:
#   change_type       covered_recipient_type  teaching_hospital_ccn  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    teaching_hospital_id  teaching_hospital_name  physician_profile_id  \
# 0                   NaN                     NaN                174740
# 1                   NaN                     NaN                154459
# 2                   NaN                     NaN                820445
# 3                   NaN                     NaN                   801
# 4                   NaN                     NaN                338981
#
#   physician_first_name physician_middle_name physician_last_name  \
# 0                 LISA                   NaN           CAPALDINI
# 1                 UTKU                   NaN            KANDEMIR
# 2                CAROL                     K                 LEE
# 3                 PAUL                   NaN                HEIM
# 4                BRUCE                    A.                CREE
#
#   physician_name_suffix recipient_primary_business_street_address_line1  \
# 0                   NaN                                    45 CASTRO ST
# 1                   NaN                             1001 POTRERO AVENUE
# 2                   NaN                                 1518 NORIEGA ST
# 3                   NaN                                     909 HYDE ST
# 4                   NaN                          675 NELSON RISING LANE
#
#   recipient_primary_business_street_address_line2 recipient_city  \
# 0                                         STE 227  SAN FRANCISCO
# 1                                         RM 3A36  SAN FRANCISCO
# 2                                       SUITE 200  SAN FRANCISCO
# 3                                       SUITE 428  SAN FRANCISCO
# 4                  UCSF MULTIPLE SCLEROSIS CENTER  SAN FRANCISCO
#
#   recipient_state recipient_zip_code recipient_country  recipient_province  \
# 0              CA              94114     United States                 NaN
# 1              CA              94110     United States                 NaN
# 2              CA         94122-4434     United States                 NaN
# 3              CA         94109-4822     United States                 NaN
# 4              CA              94158     United States                 NaN
#
#    recipient_postal_code physician_primary_type  \
# 0                    NaN         Medical Doctor
# 1                    NaN         Medical Doctor
# 2                    NaN         Medical Doctor
# 3                    NaN         Medical Doctor
# 4                    NaN         Medical Doctor
#
#                                  physician_specialty  \
# 0  Allopathic & Osteopathic Physicians|Internal M...
# 1  Allopathic & Osteopathic Physicians|Orthopaedi...
# 2     Allopathic & Osteopathic Physicians|Pediatrics
# 3  Allopathic & Osteopathic Physicians|Psychiatry...
# 4  Allopathic & Osteopathic Physicians|Psychiatry...
#
#   physician_license_state_code1  physician_license_state_code2  \
# 0                            CA                            NaN
# 1                            CA                            NaN
# 2                            CA                            NaN
# 3                            CA                            NaN
# 4                            CA                            NaN
#
#    physician_license_state_code3  physician_license_state_code4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    physician_license_state_code5  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#   submitting_applicable_manufacturer_or_applicable_gpo_name  \
# 0                                       AbbVie, Inc.
# 1                                Stryker Corporation
# 2                        Galderma Laboratories, L.P.
# 3                      Sunovion Pharmaceuticals Inc.
# 4                                   Biogen Idec Inc.
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000000204
# 1                                       100000010503
# 2                                       100000010375
# 3                                       100000000254
# 4                                       100000000193
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                                       AbbVie, Inc.
# 1                                Stryker Corporation
# 2                        Galderma Laboratories, L.P.
# 3                      Sunovion Pharmaceuticals Inc.
# 4                                   Biogen Idec Inc.
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_state  \
# 0                                                 IL
# 1                                                 MI
# 2                                                 TX
# 3                                                 MA
# 4                                                 MA
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_countr  \
# 0                                      United States
# 1                                      United States
# 2                                      United States
# 3                                      United States
# 4                                      United States
#
#    total_amount_of_payment_usdollars      date_of_payment  \
# 0                               4.29  2013-12-06 00:00:00
# 1                              15.49  2013-09-27 00:00:00
# 2                              12.49  2013-08-01 00:00:00
# 3                              13.35  2013-10-31 00:00:00
# 4                              32.26  2013-09-21 00:00:00
#
#    number_of_payments_included_in_total_amount  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#   form_of_payment_or_transfer_of_value nature_of_payment_or_transfer_of_value  \
# 0           In-kind items and services                      Food and Beverage
# 1              Cash or cash equivalent                      Food and Beverage
# 2           In-kind items and services                      Food and Beverage
# 3           In-kind items and services                      Food and Beverage
# 4              Cash or cash equivalent                      Food and Beverage
#
#   city_of_travel state_of_travel country_of_travel  \
# 0            NaN             NaN               NaN
# 1            NaN             NaN               NaN
# 2            NaN             NaN               NaN
# 3            NaN             NaN               NaN
# 4            NaN             NaN               NaN
#
#   physician_ownership_indicator third_party_payment_recipient_indicator  \
# 0                            No                  No Third Party Payment
# 1                            No                  No Third Party Payment
# 2                            No                  No Third Party Payment
# 3                            No                  No Third Party Payment
# 4                            No                  No Third Party Payment
#
#   name_of_third_party_entity_receiving_payment_or_transfer_of_val  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   charity_indicator third_party_equals_covered_recipient_indicator  \
# 0               NaN                                            NaN
# 1               NaN                                            NaN
# 2                No                                            NaN
# 3               NaN                                            NaN
# 4                No                                            NaN
#
#   contextual_information delay_in_publication_indicator  record_id  \
# 0                    NaN                             No   31094501
# 1                    NaN                             No   29893470
# 2                    NaN                             No   24534805
# 3                    NaN                             No  101274004
# 4                    NaN                             No   23682087
#
#   dispute_status_for_publication product_indicator  \
# 0                             No           Covered
# 1                             No           Covered
# 2                             No           Covered
# 3                             No           Covered
# 4                             No           Covered
#
#   name_of_associated_covered_drug_or_biological1  \
# 0                                       Androgel
# 1                                            NaN
# 2                                         EPIDUO
# 3                                         Latuda
# 4                                        TYSABRI
#
#   name_of_associated_covered_drug_or_biological2  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                      TECFIDERA
#
#   name_of_associated_covered_drug_or_biological3  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                         AVONEX
#
#   name_of_associated_covered_drug_or_biological4  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   name_of_associated_covered_drug_or_biological5  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   ndc_of_associated_covered_drug_or_biological1  \
# 0                                  0051-8462-33
# 1                                           NaN
# 2                                           NaN
# 3                                  63402-304-30
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological3  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological4  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological5  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   name_of_associated_covered_device_or_medical_supply1  \
# 0                                                NaN
# 1                             TRAUMA and EXTREMITIES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   name_of_associated_covered_device_or_medical_supply2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   name_of_associated_covered_device_or_medical_supply3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    name_of_associated_covered_device_or_medical_supply4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    name_of_associated_covered_device_or_medical_supply5  program_year  \
# 0                                                NaN             2013
# 1                                                NaN             2013
# 2                                                NaN             2013
# 3                                                NaN             2013
# 4                                                NaN             2013
#
#   payment_publication_date  related_product_indicator  \
# 0      2019-01-18 00:00:00                        NaN
# 1      2019-01-18 00:00:00                        NaN
# 2      2019-01-18 00:00:00                        NaN
# 3      2019-01-18 00:00:00                        NaN
# 4      2019-01-18 00:00:00                        NaN
#
#    covered_or_noncovered_indicator_1  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_1  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_1  covered_or_noncovered_indicator_2  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_2  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_2  covered_or_noncovered_indicator_3  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_3  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_3  covered_or_noncovered_indicator_4  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_4  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_4  covered_or_noncovered_indicator_5  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_5  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_5  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_5  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_5  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                         full_address physician_full_name
# 0      45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114                 NaN
# 1  1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA...                 NaN
# 2  1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 9...                 NaN
# 3  909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109...                 NaN
# 4  675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS...                 NaN

# %%
df['full_address'] = df['recipient_primary_business_street_address_line1'].fillna('') \
  + ' ' + df['recipient_primary_business_street_address_line2'].fillna('') \
  + ', ' + df['recipient_city'].fillna('') \
  + ', ' + df['recipient_state'].fillna('') \
  + ' ' + df['recipient_zip_code'].fillna('')

df['full_address'].replace({' ,': ','}, inplace=True, regex=True)

# %%
df.full_address.head()
# Out:
# 0        45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114
# 1    1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA...
# 2    1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 9...
# 3    909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109...
# 4    675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS...
# Name: full_address, dtype: object

# %%
example_address = df.full_address[0]

# %%
example_address
# Out:
# '45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114'

# %%
result = cg.onelineaddress(example_address)

# %%
type(result)
# Out:
# censusgeocode.censusgeocode.AddressResult

# %%
latitude = result[0]['coordinates']['x']
longitude = result[0]['coordinates']['y']
census_block = result[0]['geographies']['2010 Census Blocks'][0]['BLOCK']
census_block_group = result[0]['geographies']['2010 Census Blocks'][0]['BLKGRP']
census_tract = result[0]['geographies']['2010 Census Blocks'][0]['TRACT']
census_geoid = result[0]['geographies']['2010 Census Blocks'][0]['GEOID']

# %%
print(latitude, longitude, census_block, census_block_group, census_tract, census_geoid)
# Out:
# -122.43574 37.76856 2000 2 016900 060750169002000

# %%
df_small = df[['full_address', 'physician_last_name','physician_first_name']].head(5)

# %%
df_small
# Out:
#                                         full_address physician_last_name  \
# 0      45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114           CAPALDINI
# 1  1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA...            KANDEMIR
# 2  1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 9...                 LEE
# 3  909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109...                HEIM
# 4  675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS...                CREE
#
#   physician_first_name
# 0                 LISA
# 1                 UTKU
# 2                CAROL
# 3                 PAUL
# 4                BRUCE

# %%
df_small['census_geoid'] = None

# %%
df_small
# Out:
#                                         full_address physician_last_name  \
# 0      45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114           CAPALDINI
# 1  1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA...            KANDEMIR
# 2  1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 9...                 LEE
# 3  909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109...                HEIM
# 4  675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS...                CREE
#
#   physician_first_name census_geoid
# 0                 LISA         None
# 1                 UTKU         None
# 2                CAROL         None
# 3                 PAUL         None
# 4                BRUCE         None

# %%
for address in df_small.full_address:
    print(address)
    geo_id = cg.onelineaddress(address)
    if geo_id:
        df_small.loc[df_small.full_address == address,'census_geoid'] = geo_id[0]['geographies']['2010 Census Blocks'][0]['GEOID']
# Out:
# 45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114
# 1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA 94110
# 1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 94122-4434
# 909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109-4822
# 675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS CENTER, SAN FRANCISCO, CA 94158

# %%
df_small
# Out:
#                                         full_address physician_last_name  \
# 0      45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114           CAPALDINI
# 1  1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA...            KANDEMIR
# 2  1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 9...                 LEE
# 3  909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109...                HEIM
# 4  675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS...                CREE
#
#   physician_first_name     census_geoid
# 0                 LISA  060750169002000
# 1                 UTKU  060750228022009
# 2                CAROL  060750328023000
# 3                 PAUL  060750111003001
# 4                BRUCE             None

# %%
df_small
# Out:
#                                         full_address physician_last_name  \
# 0      45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114           CAPALDINI
# 1  1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA...            KANDEMIR
# 2  1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 9...                 LEE
# 3  909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109...                HEIM
# 4  675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS...                CREE
#
#   physician_first_name census_geoid
# 0                 LISA         None
# 1                 UTKU         None
# 2                CAROL         None
# 3                 PAUL         None
# 4                BRUCE         None

# %%
type(df_small)
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#   change_type       covered_recipient_type  teaching_hospital_ccn  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
# 2   UNCHANGED  Covered Recipient Physician                    NaN
# 3   UNCHANGED  Covered Recipient Physician                    NaN
# 4   UNCHANGED  Covered Recipient Physician                    NaN
#
#    teaching_hospital_id  teaching_hospital_name  physician_profile_id  \
# 0                   NaN                     NaN                174740
# 1                   NaN                     NaN                154459
# 2                   NaN                     NaN                820445
# 3                   NaN                     NaN                   801
# 4                   NaN                     NaN                338981
#
#   physician_first_name physician_middle_name physician_last_name  \
# 0                 LISA                   NaN           CAPALDINI
# 1                 UTKU                   NaN            KANDEMIR
# 2                CAROL                     K                 LEE
# 3                 PAUL                   NaN                HEIM
# 4                BRUCE                    A.                CREE
#
#   physician_name_suffix recipient_primary_business_street_address_line1  \
# 0                   NaN                                    45 CASTRO ST
# 1                   NaN                             1001 POTRERO AVENUE
# 2                   NaN                                 1518 NORIEGA ST
# 3                   NaN                                     909 HYDE ST
# 4                   NaN                          675 NELSON RISING LANE
#
#   recipient_primary_business_street_address_line2 recipient_city  \
# 0                                         STE 227  SAN FRANCISCO
# 1                                         RM 3A36  SAN FRANCISCO
# 2                                       SUITE 200  SAN FRANCISCO
# 3                                       SUITE 428  SAN FRANCISCO
# 4                  UCSF MULTIPLE SCLEROSIS CENTER  SAN FRANCISCO
#
#   recipient_state recipient_zip_code recipient_country  recipient_province  \
# 0              CA              94114     United States                 NaN
# 1              CA              94110     United States                 NaN
# 2              CA         94122-4434     United States                 NaN
# 3              CA         94109-4822     United States                 NaN
# 4              CA              94158     United States                 NaN
#
#    recipient_postal_code physician_primary_type  \
# 0                    NaN         Medical Doctor
# 1                    NaN         Medical Doctor
# 2                    NaN         Medical Doctor
# 3                    NaN         Medical Doctor
# 4                    NaN         Medical Doctor
#
#                                  physician_specialty  \
# 0  Allopathic & Osteopathic Physicians|Internal M...
# 1  Allopathic & Osteopathic Physicians|Orthopaedi...
# 2     Allopathic & Osteopathic Physicians|Pediatrics
# 3  Allopathic & Osteopathic Physicians|Psychiatry...
# 4  Allopathic & Osteopathic Physicians|Psychiatry...
#
#   physician_license_state_code1  physician_license_state_code2  \
# 0                            CA                            NaN
# 1                            CA                            NaN
# 2                            CA                            NaN
# 3                            CA                            NaN
# 4                            CA                            NaN
#
#    physician_license_state_code3  physician_license_state_code4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    physician_license_state_code5  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#   submitting_applicable_manufacturer_or_applicable_gpo_name  \
# 0                                       AbbVie, Inc.
# 1                                Stryker Corporation
# 2                        Galderma Laboratories, L.P.
# 3                      Sunovion Pharmaceuticals Inc.
# 4                                   Biogen Idec Inc.
#
#    applicable_manufacturer_or_applicable_gpo_making_payment_id  \
# 0                                       100000000204
# 1                                       100000010503
# 2                                       100000010375
# 3                                       100000000254
# 4                                       100000000193
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_name  \
# 0                                       AbbVie, Inc.
# 1                                Stryker Corporation
# 2                        Galderma Laboratories, L.P.
# 3                      Sunovion Pharmaceuticals Inc.
# 4                                   Biogen Idec Inc.
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_state  \
# 0                                                 IL
# 1                                                 MI
# 2                                                 TX
# 3                                                 MA
# 4                                                 MA
#
#   applicable_manufacturer_or_applicable_gpo_making_payment_countr  \
# 0                                      United States
# 1                                      United States
# 2                                      United States
# 3                                      United States
# 4                                      United States
#
#    total_amount_of_payment_usdollars      date_of_payment  \
# 0                               4.29  2013-12-06 00:00:00
# 1                              15.49  2013-09-27 00:00:00
# 2                              12.49  2013-08-01 00:00:00
# 3                              13.35  2013-10-31 00:00:00
# 4                              32.26  2013-09-21 00:00:00
#
#    number_of_payments_included_in_total_amount  \
# 0                                            1
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#   form_of_payment_or_transfer_of_value nature_of_payment_or_transfer_of_value  \
# 0           In-kind items and services                      Food and Beverage
# 1              Cash or cash equivalent                      Food and Beverage
# 2           In-kind items and services                      Food and Beverage
# 3           In-kind items and services                      Food and Beverage
# 4              Cash or cash equivalent                      Food and Beverage
#
#   city_of_travel state_of_travel country_of_travel  \
# 0            NaN             NaN               NaN
# 1            NaN             NaN               NaN
# 2            NaN             NaN               NaN
# 3            NaN             NaN               NaN
# 4            NaN             NaN               NaN
#
#   physician_ownership_indicator third_party_payment_recipient_indicator  \
# 0                            No                  No Third Party Payment
# 1                            No                  No Third Party Payment
# 2                            No                  No Third Party Payment
# 3                            No                  No Third Party Payment
# 4                            No                  No Third Party Payment
#
#   name_of_third_party_entity_receiving_payment_or_transfer_of_val  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   charity_indicator third_party_equals_covered_recipient_indicator  \
# 0               NaN                                            NaN
# 1               NaN                                            NaN
# 2                No                                            NaN
# 3               NaN                                            NaN
# 4                No                                            NaN
#
#   contextual_information delay_in_publication_indicator  record_id  \
# 0                    NaN                             No   31094501
# 1                    NaN                             No   29893470
# 2                    NaN                             No   24534805
# 3                    NaN                             No  101274004
# 4                    NaN                             No   23682087
#
#   dispute_status_for_publication product_indicator  \
# 0                             No           Covered
# 1                             No           Covered
# 2                             No           Covered
# 3                             No           Covered
# 4                             No           Covered
#
#   name_of_associated_covered_drug_or_biological1  \
# 0                                       Androgel
# 1                                            NaN
# 2                                         EPIDUO
# 3                                         Latuda
# 4                                        TYSABRI
#
#   name_of_associated_covered_drug_or_biological2  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                      TECFIDERA
#
#   name_of_associated_covered_drug_or_biological3  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                         AVONEX
#
#   name_of_associated_covered_drug_or_biological4  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   name_of_associated_covered_drug_or_biological5  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   ndc_of_associated_covered_drug_or_biological1  \
# 0                                  0051-8462-33
# 1                                           NaN
# 2                                           NaN
# 3                                  63402-304-30
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological3  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological4  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   ndc_of_associated_covered_drug_or_biological5  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   name_of_associated_covered_device_or_medical_supply1  \
# 0                                                NaN
# 1                             TRAUMA and EXTREMITIES
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   name_of_associated_covered_device_or_medical_supply2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   name_of_associated_covered_device_or_medical_supply3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    name_of_associated_covered_device_or_medical_supply4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    name_of_associated_covered_device_or_medical_supply5  program_year  \
# 0                                                NaN             2013
# 1                                                NaN             2013
# 2                                                NaN             2013
# 3                                                NaN             2013
# 4                                                NaN             2013
#
#   payment_publication_date  related_product_indicator  \
# 0      2019-01-18 00:00:00                        NaN
# 1      2019-01-18 00:00:00                        NaN
# 2      2019-01-18 00:00:00                        NaN
# 3      2019-01-18 00:00:00                        NaN
# 4      2019-01-18 00:00:00                        NaN
#
#    covered_or_noncovered_indicator_1  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_1  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_1  covered_or_noncovered_indicator_2  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_2  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_2  covered_or_noncovered_indicator_3  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_3  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_3  covered_or_noncovered_indicator_4  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_4  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_4  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_4  covered_or_noncovered_indicator_5  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#    indicate_drug_or_biological_or_device_or_medical_supply_5  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_category_or_therapeutic_area_5  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    name_of_drug_or_biological_or_device_or_medical_supply_5  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    associated_drug_or_biological_ndc_5  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                         full_address physician_full_name
# 0      45 CASTRO ST STE 227, SAN FRANCISCO, CA 94114                 NaN
# 1  1001 POTRERO AVENUE RM 3A36, SAN FRANCISCO, CA...                 NaN
# 2  1518 NORIEGA ST SUITE 200, SAN FRANCISCO, CA 9...                 NaN
# 3  909 HYDE ST SUITE 428, SAN FRANCISCO, CA 94109...                 NaN
# 4  675 NELSON RISING LANE UCSF MULTIPLE SCLEROSIS...                 NaN

# %%
df.census_geoid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ce2c3e91c753> in <module>()
# ----> 1 df.census_geoid
#
# /Users/benjaminbang/.pyenv/versions/3.6.2/envs/datasci-open-payments/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'census_geoid'
